# %%
#A:
person_dict ={'Name':'Iqra','Age':19, 'City':'Lahore','Hobbies':'reading'}
print(person_dict)
# Out:
# {'Name': 'Iqra', 'Age': 19, 'City': 'Lahore', 'Hobbies': 'reading'}

# %%
#B:
text='hello python hello everyone'
words=text.split()
word_count={}
for word in words:
    if word in word_count:
        word_count[word]+=1
    else:
        word_count[word]=1 
print(word_count)
# Out:
# {'hello': 2, 'python': 1, 'everyone': 1}

# %%
#C:
inventory={
    'desks': 25,
    'chairs': 18,
    'cupboards': 7
}
print(inventory)
# Out:
# {'desks': 25, 'chairs': 18, 'cupboards': 7}

# %%
#D:
orders=[
{'category':'books'},
{'category':'clothes'},
{'category':'books'},
{'category':'toys'},
{'category':'books'},
{'category':'books'} 
]
category_count={}
for order in orders:
    category=order['category']
category_count[category]=category_count.get(category,0)+1
most_popular=max(category_count,key=category_count.get)
print('most popular category:',most_popular)
# Out:
# most popular category: books

# %%
#E
students={
    'qurat':[75,93,68],
    'annie':[84,52,76]
}
for name,grades in students.items():
    avg=sum(grades)/len(grades)
    print(f"{name}'s average:{avg}")
# Out:
# qurat's average:78.66666666666667
# annie's average:70.66666666666667

# %%
#F:
inventory={}
inventory['laptop']={'quantity':4,'price':1500}
inventory['mouse']={'quantity':2,'price':500}
inventory['keyboard']={'quantity':5,'price':650}
print(inventory)
inventory['laptop']['quantity']= 4
print(inventory)
total_value=0
for item in inventory:
    quantity=inventory[item]['price'] 
    price=inventory[item]['price']
    total_value+=quantity*price
print('total inventory value:',total_value)
print('low stock items:')
for item in inventory:
    if inventory [item]['quantity']<5:
        print(item,'->',inventory[item])
# Out:
# {'laptop': {'quantity': 4, 'price': 1500}, 'mouse': {'quantity': 2, 'price': 500}, 'keyboard': {'quantity': 5, 'price': 650}}
# {'laptop': {'quantity': 4, 'price': 1500}, 'mouse': {'quantity': 2, 'price': 500}, 'keyboard': {'quantity': 5, 'price': 650}}
# total inventory value: 2922500
# low stock items:
# laptop -> {'quantity': 4, 'price': 1500}
# mouse -> {'quantity': 2, 'price': 500}

# %%
students = {
    "Iqra": {"Geography": 88, "English": 92},
    "Isra": {"Geography": 76, "English": 85}
}
for name, subjects in students.items():
    average = sum(subjects.values()) / len(subjects)
    print(f"{name}'s average: {average}")
# Out:
# Iqra's average: 90.0
# Isra's average: 80.5
